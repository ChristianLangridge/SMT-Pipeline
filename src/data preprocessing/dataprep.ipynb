# %%
import pandas as pd
import numpy as np 
import csv
import os 
from spatialmt.config import Paths, Dirs, setup_output_dirs, validate_raw_inputs

# %%
setup_output_dirs()
validate_raw_inputs()

# %%
tpm_data = pd.read_csv(Paths.Original_TPM_data)
print(f"Loaded TPM data: {tpm_data.shape}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tpm_data = pd.read_csv(Paths.Original_TPM_data)
#       2 print(f"Loaded TPM data: {tpm_data.shape}")
#
# AttributeError: type object 'Paths' has no attribute 'Original_TPM_data'
