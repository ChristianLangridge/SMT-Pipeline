# %%
import pandas as pd
import numpy as np 
import csv
import os 
from spatialmt.config import Paths, Dirs, setup_output_dirs, validate_raw_inputs

# %%
setup_output_dirs()
validate_raw_inputs()

# %%
tpm_data = pd.read_csv(Paths.raw_tpm_csv, sep='\t', header=0, index_col=0)
print(f"Loaded TPM data: {tpm_data.shape}")
# Out:
# Loaded TPM data: (16763, 36)

# %%
tpm_data.head()
# Out:
#                   hgnc_symbol  H9_d5_0103  H9_d7_0103  H9_d8_0103  \
# ,gene_id
# 0,ENSG00000121410        A1BG    6.921666    8.206196    6.870105
# 1,ENSG00000148584        A1CF    0.000000    0.000000    0.081884
# 2,ENSG00000175899         A2M    0.485974    0.058076    0.123172
# 3,ENSG00000166535       A2ML1    2.602018    1.184590    0.000000
# 4,ENSG00000184389     A3GALT2    0.000000    0.120808    0.000000
#
#                    H9_d10_0103  H9_d15_0103  H9_d20_0103  H9_d30_0103  \
# ,gene_id
# 0,ENSG00000121410    13.714784    18.328083     8.179570    19.459985
# 1,ENSG00000148584     0.000000     0.000000     0.000000     0.034991
# 2,ENSG00000175899     0.000000     0.541223    20.879444     3.315989
# 3,ENSG00000166535     0.364022     0.177419     0.027697     0.046011
# 4,ENSG00000184389     0.000000     0.422186     1.186320     0.328466
#
#                    H9_d5_1704  H9_d7_1704  ...  meanH9_d8   sdH9_d8  \
# ,gene_id                                   ...
# ...
